# %% [markdown]
# # Introduction
#
# Selecting specific values of a pandas DataFrame or Series to work on is an implicit step in almost any data operation you'll run, so one of the first things you need to learn in working with data in Python is how to go about selecting the data points relevant to you quickly and effectively.

# %%
import pandas as pd
df = pd.read_csv("../Datasets/PakistanDroneAttacksWithTemp Ver 9 (October 19, 2017).csv",  encoding='cp1252')
# Out:
#         S#                         Date   Time  \
# 0      1.0        Friday, June 18, 2004  22:00
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 3      4.0     Friday, January 06, 2006    NaN
# 4      5.0     Friday, January 13, 2006   3:00
# ..     ...                          ...    ...
# 400  402.0        Monday, June 12, 2017  21:00
# 401  403.0        Monday, July 03, 2017    NaN
# 402  404.0   Friday, September 15, 2017    NaN
# 403  405.0     Monday, October 16, 2017    NaN
# 404    NaN                          NaN    NaN
#
#                                  Location                 City Province  \
# 0                               Near Wana     south Waziristan     FATA
# 1            Mir Ali (Near Afghan Border)     North Waziristan     FATA
# 2                     Haisori- Miran Shah     North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana     North Waziristan     FATA
# 4                        Damadola Village       Bajaur  Agency     FATA
# ..                                    ...                  ...      ...
# 400                             Spin Thal                Hangu      KPK
# 401                                   NaN     South Waziristan     FATA
# 402                            Ghuz Ghari        Kurram Agency     FATA
# 403                            Zero-point  Lower Kurram Agency     FATA
# 404                                   NaN                  NaN      NaN
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 0             1.0       NaN      1.0            0.0  ...          NaN
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 3             1.0       NaN      NaN            NaN  ...          NaN
# 4             1.0       NaN      NaN            0.0  ...          NaN
# ..            ...       ...      ...            ...  ...          ...
# 400           1.0       NaN      NaN            0.0  ...          0.0
# 401           2.0       NaN      NaN            0.0  ...          0.0
# 402           2.0       NaN      NaN            0.0  ...          2.0
# 403           4.0       NaN      5.0            NaN  ...          NaN
# 404           NaN      49.0    662.0         1304.0  ...        402.0
#
#      Injured Max  Women/Children    \
# 0            NaN                 N
# 1            NaN                 N
# 2            2.0               NaN
# 3            2.0               NaN
# 4            2.0                 Y
# ..           ...               ...
# 400          0.0                 N
# 401          0.0                 N
# 402          2.0                 N
# 403          NaN                 N
# 404       1329.0               NaN
#
#                                 Special Mention (Site)  \
# 0    Blast occured in courtyard of the house of lon...
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 3                                                  NaN
# 4    Three houses were tarheted in Damadola village...
# ..                                                 ...
# 400  Haqqani network leader Abubakar and his partne...
# 401  a CIA-operated drone carried out a missile att...
# 402  A US drone killed three suspected Afghan Talib...
# 403  At least five suspected militants were killed ...
# 404                                                NaN
#
#                                               Comments  \
# 0                                      Village in Wana
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 3                                                  NaN
# 4    Masood Khan house was among those bombed. Want...
# ..                                                 ...
# 400  Thal city falls in Hangu district and lies clo...
# 401                                                NaN
# 402                                                NaN
# 403  Conflict of Report: Foreign media reported tha...
# 404                                                NaN
#
#                                             References  Longitude   Latitude  \
# 0         http://archives.dawn.com/2004/06/19/top1.htm  69.900000  33.033300
# 1                 http://www.msnbc.msn.com/id/7847008/  70.145500  32.974600
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500  32.974600
# 3    http://www.reuters.com/article/2007/04/27/us-p...  70.145500  32.974600
# 4    http://www.dailytimes.com.pk/default.asp?page=...  71.500000  34.683300
# ..                                                 ...        ...        ...
# 400                  https://www.dawn.com/news/1339293  33.358693  70.540720
# 401                  https://www.dawn.com/news/1343100  32.120819  69.589987
# 402  https://www.dawn.com/news/1357853; https://www...  33.732174  70.150755
# 403  http://www.thesundaily.my/news/2017/10/18/deat...        NaN        NaN
# 404                                                NaN        NaN        NaN
#
#     Temperature(C) Temperature(F)
# 0           28.475         83.255
# 1           11.475         52.655
# 2            7.080         44.744
# 3            0.535         32.963
# 4           10.025         50.045
# ..             ...            ...
# 400            NaN            NaN
# 401         23.000         74.000
# 402            NaN            NaN
# 403            NaN            NaN
# 404            NaN            NaN
#
# [405 rows x 25 columns]

# %% [markdown]
# # Native accessors
#
# Native Python objects provide  good ways of indexing data. Pandas carries all of these over, which helps make it easy to start with.
#
# Consider this DataFrame:

# %%
df
# Out:
#         S#                      Date   Time                      Location  \
# 0      1.0     Friday, June 18, 2004  22:00                     Near Wana
# 1      2.0      Sunday, May 08, 2005  23:30  Mir Ali (Near Afghan Border)
# ..     ...                       ...    ...                           ...
# 403  405.0  Monday, October 16, 2017    NaN                    Zero-point
# 404    NaN                       NaN    NaN                           NaN
#
#                     City Province  No of Strike  Al-Qaeda  Taliban  \
# 0       south Waziristan     FATA           1.0       NaN      1.0
# 1       North Waziristan     FATA           1.0       1.0      NaN
# ..                   ...      ...           ...       ...      ...
# 403  Lower Kurram Agency     FATA           4.0       NaN      5.0
# 404                  NaN      NaN           NaN      49.0    662.0
#
#      Civilians Min  ...  Injured Min  Injured Max  Women/Children    \
# 0              0.0  ...          NaN          NaN                 N
# 1              0.0  ...          NaN          NaN                 N
# ..             ...  ...          ...          ...               ...
# 403            NaN  ...          NaN          NaN                 N
# 404         1304.0  ...        402.0       1329.0               NaN
#
#                                 Special Mention (Site)  \
# 0    Blast occured in courtyard of the house of lon...
# 1    Drone struck a car driven by local warlord- ki...
# ..                                                 ...
# 403  At least five suspected militants were killed ...
# 404                                                NaN
#
#                                               Comments  \
# 0                                      Village in Wana
# 1    Civilian killied was Samiullah Khan who was a ...
# ..                                                 ...
# 403  Conflict of Report: Foreign media reported tha...
# 404                                                NaN
#
#                                             References  Longitude Latitude  \
# 0         http://archives.dawn.com/2004/06/19/top1.htm    69.9000  33.0333
# 1                 http://www.msnbc.msn.com/id/7847008/    70.1455  32.9746
# ..                                                 ...        ...      ...
# 403  http://www.thesundaily.my/news/2017/10/18/deat...        NaN      NaN
# 404                                                NaN        NaN      NaN
#
#     Temperature(C) Temperature(F)
# 0           28.475         83.255
# 1           11.475         52.655
# ..             ...            ...
# 403            NaN            NaN
# 404            NaN            NaN
#
# [405 rows x 25 columns]

# %% [markdown]
# In Python, we can access the property of an object by accessing it as an attribute. A `book` object, for example, might have a `title` property, which we can access by calling `book.title`. Columns in a pandas DataFrame work in much the same way.
#
# Hence to access the `City` property of `df` we can use:

# %%
df.City
# Out:
# 0         south Waziristan
# 1         North Waziristan
# 2         North Waziristan
# 3         North Waziristan
# 4           Bajaur  Agency
#               ...
# 400                  Hangu
# 401       South Waziristan
# 402          Kurram Agency
# 403    Lower Kurram Agency
# 404                    NaN
# Name: City, Length: 405, dtype: object

# %% [markdown]
# If we have a Python dictionary, we can access its values using the indexing (`[]`) operator. We can do the same with columns in a DataFrame:

# %%
df['City']
# Out:
# 0         south Waziristan
# 1         North Waziristan
# 2         North Waziristan
# 3         North Waziristan
# 4           Bajaur  Agency
#               ...
# 400                  Hangu
# 401       South Waziristan
# 402          Kurram Agency
# 403    Lower Kurram Agency
# 404                    NaN
# Name: City, Length: 405, dtype: object

# %% [markdown]
# These are the two ways of selecting a specific Series out of a DataFrame. Neither of them is more or less syntactically valid than the other, but the indexing operator `[]` does have the advantage that it can handle column names with reserved characters in them (e.g. if we had a `country providence` column, `df.country providence` wouldn't work).
#
# Doesn't a pandas Series look kind of like a fancy dictionary? It pretty much is, so it's no surprise that, to drill down to a single specific value, we need only use the indexing operator `[]` once more:

# %%
df['City'][0]
# Out:
# 'south Waziristan'

# %% [markdown]
# # Indexing in pandas
#
# The indexing operator and attribute selection are nice because they work just like they do in the rest of the Python ecosystem. As a novice, this makes them easy to pick up and use. However, pandas has its own accessor operators, `loc` and `iloc`. For more advanced operations, these are the ones you're supposed to be using.
#
# ### Index-based selection
#
# Pandas indexing works in one of two paradigms. The first is **index-based selection**: selecting data based on its numerical position in the data. `iloc` follows this paradigm.
#
# To select the first row of data in a DataFrame, we may use the following:

# %%
df.iloc[0]
# Out:
# S#                                                                      1.0
# Date                                                  Friday, June 18, 2004
# Time                                                                  22:00
# Location                                                          Near Wana
# City                                                       south Waziristan
# Province                                                               FATA
# No of Strike                                                            1.0
# Al-Qaeda                                                                NaN
# Taliban                                                                 1.0
# Civilians Min                                                           0.0
# Civilians Max                                                           4.0
# Foreigners Min                                                          NaN
# Foreigners Max                                                          NaN
# Total Died Min                                                          NaN
# Total Died Mix                                                          5.0
# Injured Min                                                             NaN
# Injured Max                                                             NaN
# Women/Children                                                            N
# Special Mention (Site)    Blast occured in courtyard of the house of lon...
# Comments                                                    Village in Wana
# References                     http://archives.dawn.com/2004/06/19/top1.htm
# Longitude                                                              69.9
# Latitude                                                            33.0333
# Temperature(C)                                                       28.475
# Temperature(F)                                                       83.255
# Name: 0, dtype: object

# %% [markdown]
# Both `loc` and `iloc` are row-first, column-second. This is the opposite of what we do in native Python, which is column-first, row-second.
#
# This means that it's marginally easier to retrieve rows, and marginally harder to get retrieve columns. To get a column with `iloc`, we can do the following:

# %%
df.iloc[:, 0]
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 400    402.0
# 401    403.0
# 402    404.0
# 403    405.0
# 404      NaN
# Name: S#, Length: 405, dtype: float64

# %%
df.iloc[:, 1]
# Out:
# 0            Friday, June 18, 2004
# 1             Sunday, May 08, 2005
# 2      Thursday, December 01, 2005
# 3         Friday, January 06, 2006
# 4         Friday, January 13, 2006
#                   ...
# 400          Monday, June 12, 2017
# 401          Monday, July 03, 2017
# 402     Friday, September 15, 2017
# 403       Monday, October 16, 2017
# 404                            NaN
# Name: Date, Length: 405, dtype: object

# %% [markdown]
# On its own, the `:` operator, which also comes from native Python, means "everything". When combined with other selectors, however, it can be used to indicate a range of values. For example, to select the `City` column from just the first, second, and third row, we would do:

# %%
df.iloc[:3, 4]
# Out:
# 0    south Waziristan
# 1    North Waziristan
# 2    North Waziristan
# Name: City, dtype: object

# %% [markdown]
# Or, to select just the second and third entries, we would do:

# %%
df.iloc[1:3, 4]
# Out:
# 1    North Waziristan
# 2    North Waziristan
# Name: City, dtype: object

# %% [markdown]
# It's also possible to pass a list:

# %%
df.iloc[[0, 1, 2], 4]
# Out:
# 0    south Waziristan
# 1    North Waziristan
# 2    North Waziristan
# Name: City, dtype: object

# %% [markdown]
# Finally, it's worth knowing that negative numbers can be used in selection. This will start counting forwards from the _end_ of the values. So for example here are the last five elements of the dataset.

# %%
df.iloc[-5:]
# Out:
#         S#                        Date   Time    Location  \
# 400  402.0       Monday, June 12, 2017  21:00   Spin Thal
# 401  403.0       Monday, July 03, 2017    NaN         NaN
# 402  404.0  Friday, September 15, 2017    NaN  Ghuz Ghari
# 403  405.0    Monday, October 16, 2017    NaN  Zero-point
# 404    NaN                         NaN    NaN         NaN
#
#                     City Province  No of Strike  Al-Qaeda  Taliban  \
# 400                Hangu      KPK           1.0       NaN      NaN
# 401     South Waziristan     FATA           2.0       NaN      NaN
# 402        Kurram Agency     FATA           2.0       NaN      NaN
# 403  Lower Kurram Agency     FATA           4.0       NaN      5.0
# 404                  NaN      NaN           NaN      49.0    662.0
#
#      Civilians Min  ...  Injured Min  Injured Max  Women/Children    \
# 400            0.0  ...          0.0          0.0                 N
# 401            0.0  ...          0.0          0.0                 N
# 402            0.0  ...          2.0          2.0                 N
# 403            NaN  ...          NaN          NaN                 N
# 404         1304.0  ...        402.0       1329.0               NaN
#
#                                 Special Mention (Site)  \
# 400  Haqqani network leader Abubakar and his partne...
# 401  a CIA-operated drone carried out a missile att...
# 402  A US drone killed three suspected Afghan Talib...
# 403  At least five suspected militants were killed ...
# 404                                                NaN
#
#                                               Comments  \
# 400  Thal city falls in Hangu district and lies clo...
# 401                                                NaN
# 402                                                NaN
# 403  Conflict of Report: Foreign media reported tha...
# 404                                                NaN
#
#                                             References  Longitude   Latitude  \
# 400                  https://www.dawn.com/news/1339293  33.358693  70.540720
# 401                  https://www.dawn.com/news/1343100  32.120819  69.589987
# 402  https://www.dawn.com/news/1357853; https://www...  33.732174  70.150755
# 403  http://www.thesundaily.my/news/2017/10/18/deat...        NaN        NaN
# 404                                                NaN        NaN        NaN
#
#     Temperature(C) Temperature(F)
# 400            NaN            NaN
# 401           23.0           74.0
# 402            NaN            NaN
# 403            NaN            NaN
# 404            NaN            NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Label-based selection
#
# The second paradigm for attribute selection is the one followed by the `loc` operator: **label-based selection**. In this paradigm, it's the data index value, not its position, which matters.
#
# For example, to get the first entry in `df`, we would now do the following:

# %%
df.loc[0, 'City']
# Out:
# 'south Waziristan'

# %% [markdown]
# `iloc` is conceptually simpler than `loc` because it ignores the dataset's indices. When we use `iloc` we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. `loc`, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using `loc` instead. For example, here's one operation that's much easier using `loc`:

# %%
df.loc[:, ['Date', 'Location', 'Province']]
# Out:
#                             Date                              Location  \
# 0          Friday, June 18, 2004                             Near Wana
# 1           Sunday, May 08, 2005          Mir Ali (Near Afghan Border)
# 2    Thursday, December 01, 2005                   Haisori- Miran Shah
# 3       Friday, January 06, 2006  Saidgai village- 115km north of Wana
# 4       Friday, January 13, 2006                      Damadola Village
# ..                           ...                                   ...
# 400        Monday, June 12, 2017                             Spin Thal
# 401        Monday, July 03, 2017                                   NaN
# 402   Friday, September 15, 2017                            Ghuz Ghari
# 403     Monday, October 16, 2017                            Zero-point
# 404                          NaN                                   NaN
#
#     Province
# 0       FATA
# 1       FATA
# 2       FATA
# 3       FATA
# 4       FATA
# ..       ...
# 400      KPK
# 401     FATA
# 402     FATA
# 403     FATA
# 404      NaN
#
# [405 rows x 3 columns]

# %% [markdown]
# ### Choosing between `loc` and `iloc`
#
# When choosing or transitioning between `loc` and `iloc`, there is one "gotcha" worth keeping in mind, which is that the two methods use slightly different indexing schemes.
#
# `iloc` uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So `0:10` will select entries `0,...,9`. `loc`, meanwhile, indexes inclusively. So `0:10` will select entries `0,...,10`.
#
# Why the change? Remember that loc can index any stdlib type: strings, for example. If we have a DataFrame with index values `Apples, ..., Potatoes, ...`, and we want to select "all the alphabetical fruit choices between Apples and Potatoes", then it's a lot more convenient to index `df.loc['Apples':'Potatoes']` than it is to index something like `df.loc['Apples', 'Potatoet']` (`t` coming after `s` in the alphabet).
#
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. `0,...,1000`. In this case `df.iloc[0:1000]` will return 1000 entries, while `df.loc[0:1000]` return 1001 of them! To get 1000 elements using `loc`, you will need to go one lower and ask for `df.loc[0:999]`.
#
# Otherwise, the semantics of using `loc` are the same as those for `iloc`.

# %% [markdown]
# # Manipulating the index
#
# Label-based selection derives its power from the labels in the index. Critically, the index we use is not immutable. We can manipulate the index in any way we see fit.
#
# The `set_index()` method can be used to do the job. Here is what happens when we `set_index` to the `title` field:

# %%
df.set_index("S#")
# Out:
#                               Date   Time  \
# S#
# 1.0          Friday, June 18, 2004  22:00
# 2.0           Sunday, May 08, 2005  23:30
# 3.0    Thursday, December 01, 2005    NaN
# 4.0       Friday, January 06, 2006    NaN
# 5.0       Friday, January 13, 2006   3:00
# ...                            ...    ...
# 402.0        Monday, June 12, 2017  21:00
# 403.0        Monday, July 03, 2017    NaN
# 404.0   Friday, September 15, 2017    NaN
# 405.0     Monday, October 16, 2017    NaN
# NaN                            NaN    NaN
#
#                                    Location                 City Province  \
# S#
# 1.0                               Near Wana     south Waziristan     FATA
# 2.0            Mir Ali (Near Afghan Border)     North Waziristan     FATA
# 3.0                     Haisori- Miran Shah     North Waziristan     FATA
# 4.0    Saidgai village- 115km north of Wana     North Waziristan     FATA
# 5.0                        Damadola Village       Bajaur  Agency     FATA
# ...                                     ...                  ...      ...
# 402.0                             Spin Thal                Hangu      KPK
# 403.0                                   NaN     South Waziristan     FATA
# 404.0                            Ghuz Ghari        Kurram Agency     FATA
# 405.0                            Zero-point  Lower Kurram Agency     FATA
# NaN                                     NaN                  NaN      NaN
#
#        No of Strike  Al-Qaeda  Taliban  Civilians Min  Civilians Max  ...  \
# S#                                                                    ...
# 1.0             1.0       NaN      1.0            0.0            4.0  ...
# 2.0             1.0       1.0      NaN            0.0            1.0  ...
# 3.0             1.0       1.0      NaN            0.0            1.0  ...
# 4.0             1.0       NaN      NaN            NaN            NaN  ...
# 5.0             1.0       NaN      NaN            0.0           18.0  ...
# ...             ...       ...      ...            ...            ...  ...
# 402.0           1.0       NaN      NaN            0.0            0.0  ...
# 403.0           2.0       NaN      NaN            0.0            0.0  ...
# 404.0           2.0       NaN      NaN            0.0            0.0  ...
# 405.0           4.0       NaN      5.0            NaN            NaN  ...
# NaN             NaN      49.0    662.0         1304.0         2542.0  ...
#
#        Injured Min  Injured Max  Women/Children    \
# S#
# 1.0            NaN          NaN                 N
# 2.0            NaN          NaN                 N
# 3.0            NaN          2.0               NaN
# 4.0            NaN          2.0               NaN
# 5.0            NaN          2.0                 Y
# ...            ...          ...               ...
# 402.0          0.0          0.0                 N
# 403.0          0.0          0.0                 N
# 404.0          2.0          2.0                 N
# 405.0          NaN          NaN                 N
# NaN          402.0       1329.0               NaN
#
#                                   Special Mention (Site)  \
# S#
# 1.0    Blast occured in courtyard of the house of lon...
# 2.0    Drone struck a car driven by local warlord- ki...
# 3.0                    Explosive occurred at a mud house
# 4.0                                                  NaN
# 5.0    Three houses were tarheted in Damadola village...
# ...                                                  ...
# 402.0  Haqqani network leader Abubakar and his partne...
# 403.0  a CIA-operated drone carried out a missile att...
# 404.0  A US drone killed three suspected Afghan Talib...
# 405.0  At least five suspected militants were killed ...
# NaN                                                  NaN
#
#                                                 Comments  \
# S#
# 1.0                                      Village in Wana
# 2.0    Civilian killied was Samiullah Khan who was a ...
# 3.0    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 4.0                                                  NaN
# 5.0    Masood Khan house was among those bombed. Want...
# ...                                                  ...
# 402.0  Thal city falls in Hangu district and lies clo...
# 403.0                                                NaN
# 404.0                                                NaN
# 405.0  Conflict of Report: Foreign media reported tha...
# NaN                                                  NaN
#
#                                               References  Longitude  \
# S#
# 1.0         http://archives.dawn.com/2004/06/19/top1.htm  69.900000
# 2.0                 http://www.msnbc.msn.com/id/7847008/  70.145500
# 3.0    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500
# 4.0    http://www.reuters.com/article/2007/04/27/us-p...  70.145500
# 5.0    http://www.dailytimes.com.pk/default.asp?page=...  71.500000
# ...                                                  ...        ...
# 402.0                  https://www.dawn.com/news/1339293  33.358693
# 403.0                  https://www.dawn.com/news/1343100  32.120819
# 404.0  https://www.dawn.com/news/1357853; https://www...  33.732174
# 405.0  http://www.thesundaily.my/news/2017/10/18/deat...        NaN
# NaN                                                  NaN        NaN
#
#         Latitude Temperature(C) Temperature(F)
# S#
# 1.0    33.033300         28.475         83.255
# 2.0    32.974600         11.475         52.655
# 3.0    32.974600          7.080         44.744
# 4.0    32.974600          0.535         32.963
# 5.0    34.683300         10.025         50.045
# ...          ...            ...            ...
# 402.0  70.540720            NaN            NaN
# 403.0  69.589987         23.000         74.000
# 404.0  70.150755            NaN            NaN
# 405.0        NaN            NaN            NaN
# NaN          NaN            NaN            NaN
#
# [405 rows x 24 columns]

# %% [markdown]
# This is useful if you can come up with an index for the dataset which is better than the current one.

# %% [markdown]
# # Conditional selection
#
# So far we've been indexing various strides of data, using structural properties of the DataFrame itself. To do *interesting* things with the data, however, we often need to ask questions based on conditions.
#
# For example, suppose that we're interested specifically in more-than-average Drone Attacks in North Waziristan.
#
# We can start by checking if each Attack is in North Waziristan or not:

# %%
df.City == 'North Waziristan'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 400    False
# 401    False
# 402    False
# 403    False
# 404    False
# Name: City, Length: 405, dtype: bool

# %% [markdown]
# This operation produced a Series of `True`/`False` booleans based on the `City` of each record.  This result can then be used inside of `loc` to select the relevant data:

# %%
df.loc[df.City == 'North Waziristan']
# Out:
#         S#                         Date   Time  \
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 3      4.0     Friday, January 06, 2006    NaN
# 6      7.0       Friday, April 27, 2007    NaN
# 7      8.0       Tuesday, June 19, 2007  10:30
# ..     ...                          ...    ...
# 394  395.0   Saturday, January 09, 2016    NaN
# 395  396.0     Friday, January 22, 2016    NaN
# 397  398.0     Thursday, March 02, 2017  16:00
# 398  400.0    Wednesday, April 26, 2017  12:30
# 399  401.0      Wednesday, May 24, 2017  12:00
#
#                                  Location              City Province  \
# 1            Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                     Haisori- Miran Shah  North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana  North Waziristan     FATA
# 6                         Saidgai village  North Waziristan     FATA
# 7                    MamiRogha- Dattakhel  North Waziristan     FATA
# ..                                    ...               ...      ...
# 394                         Mangroti area  North Waziristan     FATA
# 395                         Kurram agency  North Waziristan     FATA
# 397              Sara Khwa, Kurram agency  North Waziristan     FATA
# 398                     Lawara Mandi area  North Waziristan     FATA
# 399            Garvik area, Shawal Tehsil  North Waziristan     FATA
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 3             1.0       NaN      NaN            NaN  ...          NaN
# 6             1.0       NaN      NaN            0.0  ...          NaN
# 7             3.0       NaN      NaN           20.0  ...          NaN
# ..            ...       ...      ...            ...  ...          ...
# 394           1.0       NaN      NaN            NaN  ...          NaN
# 395           4.0       NaN      NaN            NaN  ...          1.0
# 397           1.0       0.0      2.0            0.0  ...          0.0
# 398           2.0       NaN      7.0            3.0  ...          NaN
# 399           1.0       NaN      NaN            NaN  ...          0.0
#
#      Injured Max  Women/Children    \
# 1            NaN                 N
# 2            2.0               NaN
# 3            2.0               NaN
# 6            2.0               NaN
# 7           15.0                 Y
# ..           ...               ...
# 394          NaN                 N
# 395          1.0                 N
# 397          0.0                 N
# 398          NaN               NaN
# 399          0.0                 N
#
#                                 Special Mention (Site)  \
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 3                                                  NaN
# 6    attack on house of Habibullah which was next t...
# 7    Explosion occured at cluster of 3 houses and t...
# ..                                                 ...
# 394   Atleast five suspected militants were killed ...
# 395  At least three people were killed and one pers...
# 397  killed two suspected militants in a border vil...
# 398  There are two militant commanders, Abdul Rehma...
# 399  The US drone attack killed three militants, in...
#
#                                               Comments  \
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 3                                                  NaN
# 6            millitanta were killed while making bombs
# 7            millitanta were killed while making bombs
# ..                                                 ...
# 394                                                NaN
# 395                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399  killing two TTP militants and a key commander ...
#
#                                             References  Longitude   Latitude  \
# 1                 http://www.msnbc.msn.com/id/7847008/  70.145500  32.974600
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500  32.974600
# 3    http://www.reuters.com/article/2007/04/27/us-p...  70.145500  32.974600
# 6    http://www.reuters.com/article/idUSISL11111020...  70.145500  32.974600
# 7    http://www.express.com.pk/epaper/PoPupwindow.a...  70.145500  32.974600
# ..                                                 ...        ...        ...
# 394  http://www.dailykashmirimages.com/Details/1003...  32.320237  69.859741
# 395  http://dunyanews.tv/en/Pakistan/324105-Three-d...  33.695975  70.336069
# 397  https://www.thenews.com.pk/print/189928-First-...  32.293811  70.105000
# 398  https://www.geo.tv/latest/139727-Suspected-US-...  33.145357  70.029226
# 399  https://www.thenews.com.pk/latest/206381-Suspe...  32.706186  69.415781
#
#     Temperature(C) Temperature(F)
# 1           11.475         52.655
# 2            7.080         44.744
# 3            0.535         32.963
# 6           25.770         78.386
# 7           24.395         75.911
# ..             ...            ...
# 394         -7.765         18.023
# 395        -14.155          6.521
# 397         23.000         73.000
# 398         29.000         85.000
# 399         26.000         80.000
#
# [289 rows x 25 columns]

# %% [markdown]
# This DataFrame has 289 rows. The original had 25. That means that around 2.8% of Attacks were in North Waziristan.
#
# Another way of seeing things
#
# We can use the ampersand (`&`) to bring the two questions together:

# %%
df.loc[(df.City == 'North Waziristan') & (df['Al-Qaeda'] == 1.0)]
# Out:
#         S#                         Date   Time  \
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 10    11.0    Tuesday, January 29, 2008   4:00
# 300  301.0        Monday, June 04, 2012   3:30
# 326  327.0    Sunday, December 09, 2012    NaN
#
#                                   Location              City Province  \
# 1             Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                      Haisori- Miran Shah  North Waziristan     FATA
# 10                        Khushali village  North Waziristan     FATA
# 300  Heshokhel Village- 3km East of Mirali  North Waziristan     FATA
# 326               Tabbi Village- Miranshah  North Waziristan     FATA
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 10            1.0       1.0      NaN            5.0  ...          NaN
# 300           1.0       1.0      0.0            0.0  ...          0.0
# 326           4.0       1.0      0.0            0.0  ...          0.0
#
#      Injured Max  Women/Children    \
# 1            NaN                 N
# 2            2.0               NaN
# 10           2.0                 Y
# 300          5.0                 N
# 326          6.0                 N
#
#                                 Special Mention (Site)  \
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 10               Missile hit a house of local resident
# 300  Al-Qaeda's Second-in-command Abu Yahya al-Libi...
# 326                   4 Missiles were fired on a house
#
#                                               Comments  \
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 10   Dead were pro taliban militants and some of th...
# 300                                                NaN
# 326  Senior Al-Qaeda Commander Muhammad Ahmed Al-Ma...
#
#                                             References  Longitude Latitude  \
# 1                 http://www.msnbc.msn.com/id/7847008/    70.1455  32.9746
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...    70.1455  32.9746
# 10   http://news.bbc.co.uk/2/hi/south_asia/7220823.stm    70.1455  32.9746
# 300  http://www.bbc.co.uk/news/world-asia-18327634 ...    70.1455  32.9746
# 326  http://www.express.com.pk/epaper/PoPupwindow.a...    70.1455  32.9746
#
#     Temperature(C) Temperature(F)
# 1           11.475         52.655
# 2            7.080         44.744
# 10           2.180         35.924
# 300         24.500         76.100
# 326          6.555         43.799
#
# [5 rows x 25 columns]

# %%
df.loc[(df.City == 'North Waziristan') | (df['Al-Qaeda'] == 1.0)]
# Out:
#         S#                         Date   Time  \
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 3      4.0     Friday, January 06, 2006    NaN
# 6      7.0       Friday, April 27, 2007    NaN
# 7      8.0       Tuesday, June 19, 2007  10:30
# ..     ...                          ...    ...
# 394  395.0   Saturday, January 09, 2016    NaN
# 395  396.0     Friday, January 22, 2016    NaN
# 397  398.0     Thursday, March 02, 2017  16:00
# 398  400.0    Wednesday, April 26, 2017  12:30
# 399  401.0      Wednesday, May 24, 2017  12:00
#
#                                  Location              City Province  \
# 1            Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                     Haisori- Miran Shah  North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana  North Waziristan     FATA
# 6                         Saidgai village  North Waziristan     FATA
# 7                    MamiRogha- Dattakhel  North Waziristan     FATA
# ..                                    ...               ...      ...
# 394                         Mangroti area  North Waziristan     FATA
# 395                         Kurram agency  North Waziristan     FATA
# 397              Sara Khwa, Kurram agency  North Waziristan     FATA
# 398                     Lawara Mandi area  North Waziristan     FATA
# 399            Garvik area, Shawal Tehsil  North Waziristan     FATA
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 3             1.0       NaN      NaN            NaN  ...          NaN
# 6             1.0       NaN      NaN            0.0  ...          NaN
# 7             3.0       NaN      NaN           20.0  ...          NaN
# ..            ...       ...      ...            ...  ...          ...
# 394           1.0       NaN      NaN            NaN  ...          NaN
# 395           4.0       NaN      NaN            NaN  ...          1.0
# 397           1.0       0.0      2.0            0.0  ...          0.0
# 398           2.0       NaN      7.0            3.0  ...          NaN
# 399           1.0       NaN      NaN            NaN  ...          0.0
#
#      Injured Max  Women/Children    \
# 1            NaN                 N
# 2            2.0               NaN
# 3            2.0               NaN
# 6            2.0               NaN
# 7           15.0                 Y
# ..           ...               ...
# 394          NaN                 N
# 395          1.0                 N
# 397          0.0                 N
# 398          NaN               NaN
# 399          0.0                 N
#
#                                 Special Mention (Site)  \
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 3                                                  NaN
# 6    attack on house of Habibullah which was next t...
# 7    Explosion occured at cluster of 3 houses and t...
# ..                                                 ...
# 394   Atleast five suspected militants were killed ...
# 395  At least three people were killed and one pers...
# 397  killed two suspected militants in a border vil...
# 398  There are two militant commanders, Abdul Rehma...
# 399  The US drone attack killed three militants, in...
#
#                                               Comments  \
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 3                                                  NaN
# 6            millitanta were killed while making bombs
# 7            millitanta were killed while making bombs
# ..                                                 ...
# 394                                                NaN
# 395                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399  killing two TTP militants and a key commander ...
#
#                                             References  Longitude   Latitude  \
# 1                 http://www.msnbc.msn.com/id/7847008/  70.145500  32.974600
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500  32.974600
# 3    http://www.reuters.com/article/2007/04/27/us-p...  70.145500  32.974600
# 6    http://www.reuters.com/article/idUSISL11111020...  70.145500  32.974600
# 7    http://www.express.com.pk/epaper/PoPupwindow.a...  70.145500  32.974600
# ..                                                 ...        ...        ...
# 394  http://www.dailykashmirimages.com/Details/1003...  32.320237  69.859741
# 395  http://dunyanews.tv/en/Pakistan/324105-Three-d...  33.695975  70.336069
# 397  https://www.thenews.com.pk/print/189928-First-...  32.293811  70.105000
# 398  https://www.geo.tv/latest/139727-Suspected-US-...  33.145357  70.029226
# 399  https://www.thenews.com.pk/latest/206381-Suspe...  32.706186  69.415781
#
#     Temperature(C) Temperature(F)
# 1           11.475         52.655
# 2            7.080         44.744
# 3            0.535         32.963
# 6           25.770         78.386
# 7           24.395         75.911
# ..             ...            ...
# 394         -7.765         18.023
# 395        -14.155          6.521
# 397         23.000         73.000
# 398         29.000         85.000
# 399         26.000         80.000
#
# [294 rows x 25 columns]

# %% [markdown]
# Pandas comes with a few built-in conditional selectors, two of which we will highlight here.
#
# The first is `isin`. `isin` is lets you select data whose value "is in" a list of values. For example, here's how we can use it to select Attacks only from **North Waziristan** or **South Waziristan**:

# %%
df.loc[df.City.isin(['North Waziristan', 'South Waziristan'])]
# Out:
#         S#                         Date   Time  \
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 3      4.0     Friday, January 06, 2006    NaN
# 6      7.0       Friday, April 27, 2007    NaN
# 7      8.0       Tuesday, June 19, 2007  10:30
# ..     ...                          ...    ...
# 395  396.0     Friday, January 22, 2016    NaN
# 397  398.0     Thursday, March 02, 2017  16:00
# 398  400.0    Wednesday, April 26, 2017  12:30
# 399  401.0      Wednesday, May 24, 2017  12:00
# 401  403.0        Monday, July 03, 2017    NaN
#
#                                  Location              City Province  \
# 1            Mir Ali (Near Afghan Border)  North Waziristan     FATA
# 2                     Haisori- Miran Shah  North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana  North Waziristan     FATA
# 6                         Saidgai village  North Waziristan     FATA
# 7                    MamiRogha- Dattakhel  North Waziristan     FATA
# ..                                    ...               ...      ...
# 395                         Kurram agency  North Waziristan     FATA
# 397              Sara Khwa, Kurram agency  North Waziristan     FATA
# 398                     Lawara Mandi area  North Waziristan     FATA
# 399            Garvik area, Shawal Tehsil  North Waziristan     FATA
# 401                                   NaN  South Waziristan     FATA
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 3             1.0       NaN      NaN            NaN  ...          NaN
# 6             1.0       NaN      NaN            0.0  ...          NaN
# 7             3.0       NaN      NaN           20.0  ...          NaN
# ..            ...       ...      ...            ...  ...          ...
# 395           4.0       NaN      NaN            NaN  ...          1.0
# 397           1.0       0.0      2.0            0.0  ...          0.0
# 398           2.0       NaN      7.0            3.0  ...          NaN
# 399           1.0       NaN      NaN            NaN  ...          0.0
# 401           2.0       NaN      NaN            0.0  ...          0.0
#
#      Injured Max  Women/Children    \
# 1            NaN                 N
# 2            2.0               NaN
# 3            2.0               NaN
# 6            2.0               NaN
# 7           15.0                 Y
# ..           ...               ...
# 395          1.0                 N
# 397          0.0                 N
# 398          NaN               NaN
# 399          0.0                 N
# 401          0.0                 N
#
#                                 Special Mention (Site)  \
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 3                                                  NaN
# 6    attack on house of Habibullah which was next t...
# 7    Explosion occured at cluster of 3 houses and t...
# ..                                                 ...
# 395  At least three people were killed and one pers...
# 397  killed two suspected militants in a border vil...
# 398  There are two militant commanders, Abdul Rehma...
# 399  The US drone attack killed three militants, in...
# 401  a CIA-operated drone carried out a missile att...
#
#                                               Comments  \
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 3                                                  NaN
# 6            millitanta were killed while making bombs
# 7            millitanta were killed while making bombs
# ..                                                 ...
# 395                                                NaN
# 397                                                NaN
# 398                                                NaN
# 399  killing two TTP militants and a key commander ...
# 401                                                NaN
#
#                                             References  Longitude   Latitude  \
# 1                 http://www.msnbc.msn.com/id/7847008/  70.145500  32.974600
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500  32.974600
# 3    http://www.reuters.com/article/2007/04/27/us-p...  70.145500  32.974600
# 6    http://www.reuters.com/article/idUSISL11111020...  70.145500  32.974600
# 7    http://www.express.com.pk/epaper/PoPupwindow.a...  70.145500  32.974600
# ..                                                 ...        ...        ...
# 395  http://dunyanews.tv/en/Pakistan/324105-Three-d...  33.695975  70.336069
# 397  https://www.thenews.com.pk/print/189928-First-...  32.293811  70.105000
# 398  https://www.geo.tv/latest/139727-Suspected-US-...  33.145357  70.029226
# 399  https://www.thenews.com.pk/latest/206381-Suspe...  32.706186  69.415781
# 401                  https://www.dawn.com/news/1343100  32.120819  69.589987
#
#     Temperature(C) Temperature(F)
# 1           11.475         52.655
# 2            7.080         44.744
# 3            0.535         32.963
# 6           25.770         78.386
# 7           24.395         75.911
# ..             ...            ...
# 395        -14.155          6.521
# 397         23.000         73.000
# 398         29.000         85.000
# 399         26.000         80.000
# 401         23.000         74.000
#
# [372 rows x 25 columns]

# %% [markdown]
# The second is `isnull` (and its companion `notnull`). These methods let you highlight values which are (or are not) empty (`NaN`). For example, to filter out Attacks lacking location in the dataset, here's what we would do:

# %%
df.loc[df.Location.notnull()]
# Out:
#         S#                         Date   Time  \
# 0      1.0        Friday, June 18, 2004  22:00
# 1      2.0         Sunday, May 08, 2005  23:30
# 2      3.0  Thursday, December 01, 2005    NaN
# 3      4.0     Friday, January 06, 2006    NaN
# 4      5.0     Friday, January 13, 2006   3:00
# ..     ...                          ...    ...
# 398  400.0    Wednesday, April 26, 2017  12:30
# 399  401.0      Wednesday, May 24, 2017  12:00
# 400  402.0        Monday, June 12, 2017  21:00
# 402  404.0   Friday, September 15, 2017    NaN
# 403  405.0     Monday, October 16, 2017    NaN
#
#                                  Location                 City Province  \
# 0                               Near Wana     south Waziristan     FATA
# 1            Mir Ali (Near Afghan Border)     North Waziristan     FATA
# 2                     Haisori- Miran Shah     North Waziristan     FATA
# 3    Saidgai village- 115km north of Wana     North Waziristan     FATA
# 4                        Damadola Village       Bajaur  Agency     FATA
# ..                                    ...                  ...      ...
# 398                     Lawara Mandi area     North Waziristan     FATA
# 399            Garvik area, Shawal Tehsil     North Waziristan     FATA
# 400                             Spin Thal                Hangu      KPK
# 402                            Ghuz Ghari        Kurram Agency     FATA
# 403                            Zero-point  Lower Kurram Agency     FATA
#
#      No of Strike  Al-Qaeda  Taliban  Civilians Min  ...  Injured Min  \
# 0             1.0       NaN      1.0            0.0  ...          NaN
# 1             1.0       1.0      NaN            0.0  ...          NaN
# 2             1.0       1.0      NaN            0.0  ...          NaN
# 3             1.0       NaN      NaN            NaN  ...          NaN
# 4             1.0       NaN      NaN            0.0  ...          NaN
# ..            ...       ...      ...            ...  ...          ...
# 398           2.0       NaN      7.0            3.0  ...          NaN
# 399           1.0       NaN      NaN            NaN  ...          0.0
# 400           1.0       NaN      NaN            0.0  ...          0.0
# 402           2.0       NaN      NaN            0.0  ...          2.0
# 403           4.0       NaN      5.0            NaN  ...          NaN
#
#      Injured Max  Women/Children    \
# 0            NaN                 N
# 1            NaN                 N
# 2            2.0               NaN
# 3            2.0               NaN
# 4            2.0                 Y
# ..           ...               ...
# 398          NaN               NaN
# 399          0.0                 N
# 400          0.0                 N
# 402          2.0                 N
# 403          NaN                 N
#
#                                 Special Mention (Site)  \
# 0    Blast occured in courtyard of the house of lon...
# 1    Drone struck a car driven by local warlord- ki...
# 2                    Explosive occurred at a mud house
# 3                                                  NaN
# 4    Three houses were tarheted in Damadola village...
# ..                                                 ...
# 398  There are two militant commanders, Abdul Rehma...
# 399  The US drone attack killed three militants, in...
# 400  Haqqani network leader Abubakar and his partne...
# 402  A US drone killed three suspected Afghan Talib...
# 403  At least five suspected militants were killed ...
#
#                                               Comments  \
# 0                                      Village in Wana
# 1    Civilian killied was Samiullah Khan who was a ...
# 2    No. 3 Al-Qaeda's Leader AbuHamza Rabia killed ...
# 3                                                  NaN
# 4    Masood Khan house was among those bombed. Want...
# ..                                                 ...
# 398                                                NaN
# 399  killing two TTP militants and a key commander ...
# 400  Thal city falls in Hangu district and lies clo...
# 402                                                NaN
# 403  Conflict of Report: Foreign media reported tha...
#
#                                             References  Longitude   Latitude  \
# 0         http://archives.dawn.com/2004/06/19/top1.htm  69.900000  33.033300
# 1                 http://www.msnbc.msn.com/id/7847008/  70.145500  32.974600
# 2    http://edition.cnn.com/2005/WORLD/asiapcf/12/0...  70.145500  32.974600
# 3    http://www.reuters.com/article/2007/04/27/us-p...  70.145500  32.974600
# 4    http://www.dailytimes.com.pk/default.asp?page=...  71.500000  34.683300
# ..                                                 ...        ...        ...
# 398  https://www.geo.tv/latest/139727-Suspected-US-...  33.145357  70.029226
# 399  https://www.thenews.com.pk/latest/206381-Suspe...  32.706186  69.415781
# 400                  https://www.dawn.com/news/1339293  33.358693  70.540720
# 402  https://www.dawn.com/news/1357853; https://www...  33.732174  70.150755
# 403  http://www.thesundaily.my/news/2017/10/18/deat...        NaN        NaN
#
#     Temperature(C) Temperature(F)
# 0           28.475         83.255
# 1           11.475         52.655
# 2            7.080         44.744
# 3            0.535         32.963
# 4           10.025         50.045
# ..             ...            ...
# 398         29.000         85.000
# 399         26.000         80.000
# 400            NaN            NaN
# 402            NaN            NaN
# 403            NaN            NaN
#
# [402 rows x 25 columns]

# %% [markdown]
# # Assigning data
#
# Going the other way, assigning data to a DataFrame is easy. You can assign either a constant value:

# %%
df['critic'] = 'everyone'
df['critic']
# Out:
# 0      everyone
# 1      everyone
# 2      everyone
# 3      everyone
# 4      everyone
#          ...
# 400    everyone
# 401    everyone
# 402    everyone
# 403    everyone
# 404    everyone
# Name: critic, Length: 405, dtype: object

# %% [markdown]
# Or with an iterable of values:

# %%
df['index_backwards'] = range(len(df), 0, -1)
df['index_backwards']
# Out:
# 0      405
# 1      404
# 2      403
# 3      402
# 4      401
#       ...
# 400      5
# 401      4
# 402      3
# 403      2
# 404      1
# Name: index_backwards, Length: 405, dtype: int64
